# %% [markdown]
# <a href="https://colab.research.google.com/github/nadilajm/DPP-11/blob/main/sesi_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as mt
import pandas as pd

# %%
df = pd.read_csv('/data_mobil.csv') # read csv dengan library pandas
df # untuk menampilkan data
# Out:
#                          Merk  Brand  Transmisi    cc      km  tahun  \
# 0       Toyota Kijang Innova       1          1  1998   71500   2018
# 1              Toyota Sienta       1          1  1497   90000   2016
# 2            Toyota Fortuner       1          1  2393   15000   2021
# 3            Toyota Fortuner       1          1  2393   75000   2016
# 4             Toyota Harrier       1          1  1986   65000   2015
# 5   Toyota Camry Hybrid Sedan      1          1  2487    6000   2021
# 6              Toyota Alphard      1          1  2494   25000   2020
# 7               Toyota Avanza      1          1  1496   70000   2017
# 8                Toyota Yaris      1          1  1496   25000   2018
# 9                Toyota Camry      1          1  2494   25000   2019
# 10              Toyota Avanza      1          1  1496  100000   2016
# 11                Toyota Vios      1          1  1496   65000   2018
# 12               Toyota Camry      1          1  2494   93000   2013
# ...
